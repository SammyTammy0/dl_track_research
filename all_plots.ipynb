# %%
import matplotlib.pyplot as plt

# %%
dir1="3_convolutions_performance/dropout0.4"
dir2="6_convolutions_performance/dropout0.4"

# %%
acc_files1= [dir1+"/acc_ve_va_ym",
             dir1+"/val_acc_ve_va_ym"]
acc_files2= [dir2+"/acc_ve_va_ym",
             dir2+"/val_acc_ve_va_ym"]
loss_files1=[dir1+"/loss_ve_va_ym",
             dir1+"/val_loss_ve_va_ym"]
loss_files2=[dir2+"/loss_ve_va_ym",
             dir2+"/val_loss_ve_va_ym"]

# %%
def get_data(filename):
    items=[]
    with open(filename, "r") as f:
        for line in f:
            items.append(float(line))
    return items

# %%
epochs = range(1, len(current_plot1[0])+1)

# %%
import matplotlib.pyplot as plt

plt.xlabel("Epochs")
plt.ylabel("Loss")
plt.plot(epochs, get_data(loss_files1[0]), "bo", alpha=0.2, label="Training loss")
plt.plot(epochs, get_data(loss_files1[1]), "b", label="Validation loss")
plt.plot(epochs, get_data(loss_files2[0]), "ro", alpha=0.2, label="Training loss")
plt.plot(epochs, get_data(loss_files2[1]), "r", label="Validation loss")
plt.title("Loss per Epoch")
plt.legend()
plt.savefig("loss_plot.png")

# %%
import matplotlib.pyplot as plt

plt.xlabel("Epochs")
plt.ylabel("Accuracy")
plt.plot(epochs, get_data(acc_files1[0]), "bo", alpha=0.2, label="Training accuracy")
plt.plot(epochs, get_data(acc_files1[1]), "b", label="Validation accuracy")
plt.plot(epochs, get_data(acc_files2[0]), "ro", alpha=0.2, label="Training accuracy")
plt.plot(epochs, get_data(acc_files2[1]), "r", label="Validation accuracy")
plt.title("Accuracy per Epoch")
plt.legend()
plt.savefig("accuracy_plot.png")
